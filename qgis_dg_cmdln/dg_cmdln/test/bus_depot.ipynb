# %%
# %load_ext autoreload

# %%
# %autoreload 1

# %%
import sys
sys.path.append(r'C:\Users\Rahul\AppData\Roaming\QGIS\QGIS3\profiles\default\python\plugins\dg_qgis\qgis_dg_cmdln\dg_cmdln')

# %%
import dg, dg.pt, dg.osm

# %%
# %aimport dg, dg.pt, dg.osm

# %%
bd = dg.pt.BusDepot()
bd.read_data_directory(r'C:\Users\Rahul\AppData\Roaming\QGIS\QGIS3\profiles\default\python\plugins\dg_qgis\qgis_dg_cmdln\dg_cmdln\test\Shahapur')
bd.write_gtfs_zipfile(r'C:\Users\Rahul\AppData\Roaming\QGIS\QGIS3\profiles\default\python\plugins\dg_qgis\qgis_dg_cmdln\dg_cmdln\test\Shahapur')
dg.pt.save_obj_bus_depot(bd, r'C:\Users\Rahul\AppData\Roaming\QGIS\QGIS3\profiles\default\python\plugins\dg_qgis\qgis_dg_cmdln\dg_cmdln\test\Shahapur\bus_depot.pkl')
# Out:
# agency_id,agency_name,agency_url,agency_timezone
# MSRTC,Maharashtra State Road Transport Corporation,https://msrtc.maharashtra.gov.in/,Asia/Kolkata
#
#            stop_name   stop_lat   stop_lon
# stop_id
# AASANGAON  AASANGAON  19.440714  73.306380
# AGHAI          AGHAI  19.567035  73.239666
# ALYANI        ALYANI  19.354225  73.406887
# AMBADI        AMBADI  19.471582  73.083962
# AMBARJE      AMBARJE  19.338047  73.308235
# ...              ...        ...        ...
# VAGHIVALI  VAGHIVALI  19.567088  73.239657
# VAITARNA    VAITARNA  19.650427  73.290294
# VASHIND      VASHIND  19.412544  73.263437
# VASHIND_B  VASHIND_B  19.412544  73.263437
# WADA            WADA  19.654520  73.147529
#
# [86 rows x 3 columns]
#      route_id route_short_name  route_type
# 0       17513        AASA_ALYA           3
# 4        3872        AASA_APAT           3
# 7        3869        AASA_ASHT           3
# 11       3861        AASA_BABA           3
# 12      95447        AASA_BELA           3
# ...

# %%
bd_ = dg.pt.load_obj_bus_depot(r'C:\Users\Rahul\AppData\Roaming\QGIS\QGIS3\profiles\default\python\plugins\dg_qgis\qgis_dg_cmdln\dg_cmdln\test\Shahapur\bus_depot.pkl')

# %%
bd.data_dict
# Out:
# {'sources': {'Id': None,
#   'types': {'directory': {'data_keys': ['stops', 'form_4'], 'dirpath': None},
#    'api_thru_pkg': {'data_keys': ['osm_graph'], 'call_signature': None}},
#   'data': {'stops':     Unnamed: 0       name                    village    taluka   latitude  \
#    0            0  AASANGAON  Asangaon (CT) - Ward No.1  SHAHAPUR  19.440714
#    1            1      AGHAI                      Aghai  SHAHAPUR  19.567035
#    2            2     ALYANI                     Alyani  SHAHAPUR  19.354225
#    3            3     AMBADI                     Ambadi  BHIVANDI  19.471582
#    4            4    AMBARJE                    Ambarje  SHAHAPUR  19.338047
#    ..         ...        ...                        ...       ...        ...
#    81          81  VAGHIVALI                      Aghai  SHAHAPUR  19.567088
#    82          82   VAITARNA                     Belvad  SHAHAPUR  19.650427
#    83          83    VASHIND   Vashind (CT) - Ward No.1  SHAHAPUR  19.412544
# ...

# %%
import osmnx
import geopandas as gpd

# %%
stops_df = bd.data_dict['GTFS']['stops.txt']

# %%
bd.load_osm(district='Thane', taluka='Shahapur')

# %%
osmnx.plot_graph(bd.data_dict['sources']['data']['osm_graph'])
# Out:
# (<Figure size 800x800 with 1 Axes>, <AxesSubplot: >)

# %%
dg.pt.save_obj_bus_depot(bd, r'C:\Users\Rahul\AppData\Roaming\QGIS\QGIS3\profiles\default\python\plugins\dg_qgis\qgis_dg_cmdln\dg_cmdln\test\Shahapur\bus_depot.pkl')

# %%
bd.digest_stops()

# %%
dg.pt.save_obj_bus_depot(bd, r'C:\Users\Rahul\AppData\Roaming\QGIS\QGIS3\profiles\default\python\plugins\dg_qgis\qgis_dg_cmdln\dg_cmdln\test\Shahapur\bus_depot.pkl')

# %%
bd = dg.pt.load_obj_bus_depot(r'C:\Users\Rahul\AppData\Roaming\QGIS\QGIS3\profiles\default\python\plugins\dg_qgis\qgis_dg_cmdln\dg_cmdln\test\Shahapur\bus_depot.pkl')

# %%
bd.digest_stops()
# Out:
# D:\iitbgis\work\Transport\code\DG_venv\Lib\site-packages\pandas\core\dtypes\cast.py:127: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)

# %%
dg.pt.save_obj_bus_depot(bd, r'C:\Users\Rahul\AppData\Roaming\QGIS\QGIS3\profiles\default\python\plugins\dg_qgis\qgis_dg_cmdln\dg_cmdln\test\Shahapur\bus_depot.pkl')

# %%
bd = dg.pt.load_obj_bus_depot(r'C:\Users\Rahul\AppData\Roaming\QGIS\QGIS3\profiles\default\python\plugins\dg_qgis\qgis_dg_cmdln\dg_cmdln\test\Shahapur\bus_depot.pkl')

# %%
ax = bd.data_dict['GPKG']['dg_stops'].plot()
bd.data_dict['GPKG']['dg_stops_nearest_nodes'].plot(ax=ax)
bd.data_dict['GPKG']['dg_stops_route_to_nearest_node'].plot(ax=ax)
# Out:
# <AxesSubplot: >

# %%
bd.save_gpkg(r'C:\Users\Rahul\AppData\Roaming\QGIS\QGIS3\profiles\default\python\plugins\dg_qgis\qgis_dg_cmdln\dg_cmdln\test\Shahapur\bus_depot.gpkg')

# %%
bd.write_gtfs_zipfile(r'C:\Users\Rahul\AppData\Roaming\QGIS\QGIS3\profiles\default\python\plugins\dg_qgis\qgis_dg_cmdln\dg_cmdln\test\Shahapur')
# Out:
# agency_id,agency_name,agency_url,agency_timezone
# MSRTC,Maharashtra State Road Transport Corporation,https://msrtc.maharashtra.gov.in/,Asia/Kolkata
#
#            stop_name   stop_lat   stop_lon
# stop_id
# AASANGAON  AASANGAON  19.440714  73.306380
# AGHAI          AGHAI  19.567035  73.239666
# ALYANI        ALYANI  19.354225  73.406887
# AMBADI        AMBADI  19.471582  73.083962
# AMBARJE      AMBARJE  19.338047  73.308235
# ...              ...        ...        ...
# VAGHIVALI  VAGHIVALI  19.567088  73.239657
# VAITARNA    VAITARNA  19.650427  73.290294
# VASHIND      VASHIND  19.412544  73.263437
# VASHIND_B  VASHIND_B  19.412544  73.263437
# WADA            WADA  19.654520  73.147529
#
# [86 rows x 3 columns]
#          route_short_name  route_type
# route_id
# 17513           AASA_ALYA           3
# 3872            AASA_APAT           3
# 3869            AASA_ASHT           3
# 3861            AASA_BABA           3
# 95447           AASA_BELA           3
# ...

# %%
bd.digest_routes()
# Out:
# D:\iitbgis\work\Transport\code\DG_venv\Lib\site-packages\pandas\core\dtypes\inference.py:387: ShapelyDeprecationWarning: Iteration over multi-part geometries is deprecated and will be removed in Shapely 2.0. Use the `geoms` property to access the constituent parts of a multi-part geometry.
#   iter(obj)  # Can iterate over it.
# D:\iitbgis\work\Transport\code\DG_venv\Lib\site-packages\pandas\core\dtypes\inference.py:388: ShapelyDeprecationWarning: __len__ for multi-part geometries is deprecated and will be removed in Shapely 2.0. Check the length of the `geoms` property instead to get the  number of parts of a multi-part geometry.
#   len(obj)  # Has a length associated with it.
# D:\iitbgis\work\Transport\code\DG_venv\Lib\site-packages\pandas\core\dtypes\cast.py:1784: ShapelyDeprecationWarning: __len__ for multi-part geometries is deprecated and will be removed in Shapely 2.0. Check the length of the `geoms` property instead to get the  number of parts of a multi-part geometry.
# ...

# %%
bd.data_dict['GPKG']['trips'].dtypes
# Out:
# stops_in_sequence                 object
# nearest_osmids_sequence           object
# shortest_path_route_geometry    geometry
# dtype: object

# %%
bd.save_gpkg(r'C:\Users\Rahul\AppData\Roaming\QGIS\QGIS3\profiles\default\python\plugins\dg_qgis\qgis_dg_cmdln\dg_cmdln\test\Shahapur\bus_depot.gpkg')
